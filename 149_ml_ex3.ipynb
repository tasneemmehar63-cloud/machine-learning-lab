# %%
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# %pip install scipy
# %pip install tensorflow
# %pip install keras
# %pip install opencv-python
# %pip install pillow
# %pip install jupyter
import numpy as np
import matplotlib.pyplot as plt
import mglearn
import tensorflow as tf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in ./.local/lib/python3.8/site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.8/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.8/site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.local/lib/python3.8/site-packages (from pandas) (2026.3)
# Requirement already satisfied: numpy>=1.20.3 in ./.local/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.14.0)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in ./.local/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.8/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.local/lib/python3.8/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in ./.local/lib/python3.8/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in ./.local/lib/python3.8/site-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=6.2.0 in ./.local/lib/python3.8/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.local/lib/python3.8/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.local/lib/python3.8/site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in ./.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib) (1.14.0)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in ./.local/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./.local/lib/python3.8/site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=1.2 in ./.local/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./.local/lib/python3.8/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.2)
# Requirement already satisfied: pillow>=6.2.0 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in ./.local/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.1 in ./.local/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: zipp>=3.1.0 in ./.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.14.0)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in ./.local/lib/python3.8/site-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in ./.local/lib/python3.8/site-packages (from scikit-learn) (1.24.3)
# Requirement already satisfied: scipy>=1.5.0 in ./.local/lib/python3.8/site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in ./.local/lib/python3.8/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./.local/lib/python3.8/site-packages (from scikit-learn) (3.5.0)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scipy in ./.local/lib/python3.8/site-packages (1.10.1)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in ./.local/lib/python3.8/site-packages (from scipy) (1.24.3)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tensorflow in ./.local/lib/python3.8/site-packages (2.13.1)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in ./.local/lib/python3.8/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in ./.local/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.8/site-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: h5py>=2.9.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in ./.local/lib/python3.8/site-packages (from tensorflow) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: numpy<=1.24.3,>=1.22 in ./.local/lib/python3.8/site-packages (from tensorflow) (1.24.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.8/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in ./.local/lib/python3.8/site-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.8/site-packages (from tensorflow) (4.25.9)
# Requirement already satisfied: setuptools in ./.local/lib/python3.8/site-packages (from tensorflow) (75.3.4)
# Requirement already satisfied: six>=1.12.0 in /usr/lib/python3/dist-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in ./.local/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (2.4.0)
# Collecting typing-extensions<4.6.0,>=3.6.6 (from tensorflow)
#   Using cached typing_extensions-4.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: wrapt>=1.11.0 in ./.local/lib/python3.8/site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.8/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.local/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./.local/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.50.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in ./.local/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in ./.local/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.7)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.local/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (2.32.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.local/lib/python3.8/site-packages (from tensorboard<2.14,>=2.13->tensorflow) (3.0.6)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in ./.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (45.0.7)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./.local/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.local/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (8.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.local/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (1.25.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow) (2.1.5)
# Requirement already satisfied: cffi>=1.14 in ./.local/lib/python3.8/site-packages (from cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (1.17.1)
# Requirement already satisfied: zipp>=3.20 in ./.local/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.14,>=2.13->tensorflow) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in ./.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (0.6.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow) (3.1.0)
# Requirement already satisfied: pycparser in ./.local/lib/python3.8/site-packages (from cffi>=1.14->cryptography>=38.0.3->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow) (2.23)
# Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.2
#     Uninstalling typing_extensions-4.13.2:
#       Successfully uninstalled typing_extensions-4.13.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# exceptiongroup 1.3.1 requires typing-extensions>=4.6.0; python_version < "3.13", but you have typing-extensions 4.5.0 which is incompatible.
# Successfully installed typing-extensions-4.5.0
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in ./.local/lib/python3.8/site-packages (2.13.1)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in ./.local/lib/python3.8/site-packages (5.0.0.93)
# Requirement already satisfied: numpy<2.0 in ./.local/lib/python3.8/site-packages (from opencv-python) (1.24.3)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pillow in ./.local/lib/python3.8/site-packages (10.4.0)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: jupyter in ./.local/lib/python3.8/site-packages (1.1.1)
# Requirement already satisfied: notebook in ./.local/lib/python3.8/site-packages (from jupyter) (7.3.3)
# Requirement already satisfied: jupyter-console in ./.local/lib/python3.8/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in ./.local/lib/python3.8/site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in ./.local/lib/python3.8/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: ipywidgets in ./.local/lib/python3.8/site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in ./.local/lib/python3.8/site-packages (from jupyter) (4.3.8)
# Requirement already satisfied: comm>=0.1.1 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (8.12.3)
# Requirement already satisfied: jupyter-client>=6.1.12 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (26.2)
# Requirement already satisfied: psutil in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (7.2.2)
# Requirement already satisfied: pyzmq>=24 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.1 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: traitlets>=5.4.0 in ./.local/lib/python3.8/site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in ./.local/lib/python3.8/site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in ./.local/lib/python3.8/site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in ./.local/lib/python3.8/site-packages (from jupyter-console->jupyter) (3.0.52)
# Requirement already satisfied: pygments in ./.local/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.19.2)
# Requirement already satisfied: async-lru>=1.0.0 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: importlib-metadata>=4.8.3 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (8.5.0)
# Requirement already satisfied: importlib-resources>=1.4 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (6.4.5)
# Requirement already satisfied: jinja2>=3.0.3 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (75.3.4)
# Requirement already satisfied: tomli>=1.2.2 in ./.local/lib/python3.8/site-packages (from jupyterlab->jupyter) (2.4.1)
# Requirement already satisfied: beautifulsoup4 in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in ./.local/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (3.3.3)
# Requirement already satisfied: nbclient>=0.5.0 in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (0.10.1)
# Requirement already satisfied: nbformat>=5.7 in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./.local/lib/python3.8/site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.local/lib/python3.8/site-packages (from async-lru>=1.0.0->jupyterlab->jupyter) (4.5.0)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (1.14.0)
# Requirement already satisfied: webencodings in ./.local/lib/python3.8/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.3,>=1.1.0 in ./.local/lib/python3.8/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: anyio in ./.local/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.5.2)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2019.11.28)
# Requirement already satisfied: httpcore==1.* in ./.local/lib/python3.8/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in /usr/lib/python3/dist-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2.8)
# Requirement already satisfied: h11>=0.16 in ./.local/lib/python3.8/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in ./.local/lib/python3.8/site-packages (from importlib-metadata>=4.8.3->jupyterlab->jupyter) (3.20.2)
# Requirement already satisfied: backcall in ./.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: decorator in ./.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.3.1)
# Requirement already satisfied: jedi>=0.16 in ./.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: pickleshare in ./.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: stack-data in ./.local/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /usr/lib/python3/dist-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.local/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in ./.local/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in ./.local/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in ./.local/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in ./.local/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in ./.local/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in ./.local/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.4)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.local/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.21.2)
# Requirement already satisfied: wcwidth in ./.local/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.8.2)
# Requirement already satisfied: soupsieve>=1.6.1 in ./.local/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.7)
# Requirement already satisfied: sniffio>=1.1 in ./.local/lib/python3.8/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./.local/lib/python3.8/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in ./.local/lib/python3.8/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in ./.local/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2026.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.local/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.7)
# Requirement already satisfied: attrs>=22.2.0 in ./.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.12.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in ./.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in ./.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.local/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.20.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./.local/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/lib/python3/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.3.1)
# Requirement already satisfied: rfc3339-validator in ./.local/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./.local/lib/python3.8/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.local/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (1.25.8)
# Requirement already satisfied: ptyprocess in ./.local/lib/python3.8/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in ./.local/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.local/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (3.0.2)
# Requirement already satisfied: pure-eval in ./.local/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Collecting typing-extensions>=4.0.0 (from async-lru>=1.0.0->jupyterlab->jupyter)
#   Using cached typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: fqdn in ./.local/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in ./.local/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./.local/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: uri-template in ./.local/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./.local/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in ./.local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in ./.local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: arrow>=0.15.0 in ./.local/lib/python3.8/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.4.0)
# Requirement already satisfied: backports.zoneinfo==0.2.1 in ./.local/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.2.1)
# Using cached typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.23ubuntu1'
# WARNING: Error parsing dependencies of python-debian: Invalid version: '0.1.36ubuntu1'
# Installing collected packages: typing-extensions
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.1 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.13.2 which is incompatible.
# Successfully installed typing-extensions-4.13.2
# Note: you may need to restart the kernel to use updated packages.
# 2026-07-28 10:12:48.248877: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-28 10:12:48.280642: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-07-28 10:12:48.281152: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-07-28 10:12:48.860738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.datasets import fetch_lfw_people
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input,Dense

# %%
np.random.seed(180)
tf.random.set_seed(180)

# %%
people=fetch_lfw_people(min_faces_per_person=20,resize=0.7)
print(people.data.shape)
print(people.target.shape)
image_shape=people.images[0].shape
# Out:
# (3023, 5655)
# (3023,)

# %%
fix,axes=plt.subplots(2,5,figsize=(15,8),subplot_kw={'xticks':(),'yticks':()})
for target,image,ax in zip(people.target,people.images,axes.ravel()):
    ax.imshow(image)
    ax.set_title(people.target_names[target])

# %%
plt.show()

# %%
X_train,X_test,y_train,y_test=train_test_split(people.data,people.target,test_size=0.2,random_state=20)
y_train=y_train.astype(int)
y_test=y_test.astype(int)
batch_size=len(X_train)
print(X_train.shape,y_train.shape,y_test.shape)
print("people.images.shape:{}".format(people.images.shape))
print("Number of classes:{}".format(len(people.target_names)))
# Out:
# (2418, 5655) (2418,) (605,)
# people.images.shape:(3023, 87, 65)
# Number of classes:62

# %%
count=np.bincount(people.target)
for i,(count,name)in enumerate(zip(count,people.target_names)):
    print("{0:25}{1:3}".format(name,count),end=" ")
    if(i+1)%3==0:
        print()
# Out:
# Alejandro Toledo          39 Alvaro Uribe              35 Amelie Mauresmo           21
# Andre Agassi              36 Angelina Jolie            20 Ariel Sharon              77
# Arnold Schwarzenegger     42 Atal Bihari Vajpayee      24 Bill Clinton              29
# Carlos Menem              21 Colin Powell             236 David Beckham             31
# Donald Rumsfeld          121 George Robertson          22 George W Bush            530
# Gerhard Schroeder        109 Gloria Macapagal Arroyo   44 Gray Davis                26
# Guillermo Coria           30 Hamid Karzai              22 Hans Blix                 39
# Hugo Chavez               71 Igor Ivanov               20 Jack Straw                28
# Jacques Chirac            52 Jean Chretien             55 Jennifer Aniston          21
# Jennifer Capriati         42 Jennifer Lopez            21 Jeremy Greenstock         24
# Jiang Zemin               20 John Ashcroft             53 John Negroponte           31
# Jose Maria Aznar          23 Juan Carlos Ferrero       28 Junichiro Koizumi         60
# Kofi Annan                32 Laura Bush                41 Lindsay Davenport         22
# Lleyton Hewitt            41 Luiz Inacio Lula da Silva 48 Mahmoud Abbas             29
# Megawati Sukarnoputri     33 Michael Bloomberg         20 Naomi Watts               22
# Nestor Kirchner           37 Paul Bremer               20 Pete Sampras              22
# Recep Tayyip Erdogan      30 Ricardo Lagos             27 Roh Moo-hyun              32
# Rudolph Giuliani          26 Saddam Hussein            23 Serena Williams           52
# Silvio Berlusconi         33 Tiger Woods               23 Tom Daschle               25
# Tom Ridge                 33 Tony Blair               144 Vicente Fox               32
# Vladimir Putin            49 Winona Ryder              24

# %%
mask=np.zeros(people.target.shape,dtype=np.bool_)
for target in np.unique(people.target):
    mask[np.where(people.target==target)[0][:50]]=True
    X_people=people.data[mask]
    y_people=people.target[mask]
    X_people=X_people/255.0

# %%
X_train,X_test,y_train,y_test=train_test_split(X_people,y_people,stratify=y_people,random_state=0)
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
print("Test set score of 1-nn:{:.2f}".format(knn.score(X_test,y_test)))
# Out:
# Test set score of 1-nn:0.22

# %%
mglearn.plots.plot_pca_whitening()
plt.show()
pca=PCA(n_components=100,whiten=True,random_state=0).fit(X_train)
X_train_pca=pca.transform(X_train)
X_test_pca=pca.transform(X_test)
print("X_train_pca.shape:{}".format(X_train_pca.shape))
knn=KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train_pca,y_train)
print("Test set accuracy:{:.2f}".format(knn.score(X_test_pca,y_test)))
print("pca.components_.shape:{}".format(pca.components_.shape))
# Out:
# X_train_pca.shape:(1547, 100)
# Test set accuracy:0.30
# pca.components_.shape:(100, 5655)

# %%
fix,axes=plt.subplots(
    3,
    5,
    figsize=(15,12),
    subplot_kw={'xticks':(),'yticks':()}
)
for i,(component,ax)in enumerate(
    zip(pca.components_,axes.ravel())):
   ax.imshow(
       component.reshape(image_shape),cmap='viridis'
   )
   ax.set_title("{}.component".format(i+1)
               )
plt.show()

# %%
scaler=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train_pca)
X_test_scaled=scaler.transform(X_test_pca)

# %%
model=Sequential([Input(shape=(100,)),Dense(300,activation='relu'),Dense(100,activation='relu'),Dense(len(np.unique(y_train)),activation='softmax')])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X_train_scaled,y_train,batch_size=50,epochs=20,shuffle=False,verbose=1)
# Out:
# Epoch 1/20
# 31/31 [==============================] - 0s 1ms/step - loss: 4.1279 - accuracy: 0.0233
# Epoch 2/20
# 31/31 [==============================] - 0s 1ms/step - loss: 4.0836 - accuracy: 0.0233
# Epoch 3/20
# 31/31 [==============================] - 0s 1ms/step - loss: 4.0564 - accuracy: 0.0427
# Epoch 4/20
# 31/31 [==============================] - 0s 1ms/step - loss: 4.0310 - accuracy: 0.0627
# Epoch 5/20
# 31/31 [==============================] - 0s 974us/step - loss: 3.9995 - accuracy: 0.0621
# Epoch 6/20
# 31/31 [==============================] - 0s 977us/step - loss: 3.9608 - accuracy: 0.0905
# Epoch 7/20
# 31/31 [==============================] - 0s 1ms/step - loss: 3.9107 - accuracy: 0.1131
# Epoch 8/20
# 31/31 [==============================] - 0s 1ms/step - loss: 3.8467 - accuracy: 0.1357
# Epoch 9/20
# 31/31 [==============================] - 0s 1ms/step - loss: 3.7697 - accuracy: 0.1590
# Epoch 10/20
# 31/31 [==============================] - 0s 980us/step - loss: 3.6733 - accuracy: 0.2010
# Epoch 11/20
# 31/31 [==============================] - 0s 974us/step - loss: 3.5502 - accuracy: 0.2217
# Epoch 12/20
# 31/31 [==============================] - 0s 1ms/step - loss: 3.4140 - accuracy: 0.2592
# Epoch 13/20
# 31/31 [==============================] - 0s 1ms/step - loss: 3.2715 - accuracy: 0.2786
# Epoch 14/20
# 31/31 [==============================] - 0s 979us/step - loss: 3.1214 - accuracy: 0.3226
# Epoch 15/20
# 31/31 [==============================] - 0s 992us/step - loss: 2.9712 - accuracy: 0.3588
# Epoch 16/20
# 31/31 [==============================] - 0s 992us/step - loss: 2.8250 - accuracy: 0.3833
# Epoch 17/20
# 31/31 [==============================] - 0s 979us/step - loss: 2.6846 - accuracy: 0.4137
# Epoch 18/20
# 31/31 [==============================] - 0s 967us/step - loss: 2.5552 - accuracy: 0.4415
# Epoch 19/20
# 31/31 [==============================] - 0s 989us/step - loss: 2.4362 - accuracy: 0.4557
# Epoch 20/20
# 31/31 [==============================] - 0s 996us/step - loss: 2.3267 - accuracy: 0.4822

# %%
loss,accuracy=model.evaluate(X_test_scaled,y_test,verbose=1)
print("Test Loss:",loss)
print("Test Accuracy:",accuracy)
# Out:
# 17/17 [==============================] - 0s 828us/step - loss: 2.7319 - accuracy: 0.3430
# Test Loss: 2.7319090366363525
# Test Accuracy: 0.34302327036857605
